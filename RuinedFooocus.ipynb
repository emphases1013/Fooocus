# %% [markdown]
# <a href="https://colab.research.google.com/github/emphases1013/Fooocus/blob/main/RuinedFooocus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y cudf-cu12 cuml-cu12 dask-cudf-cu12 nx-cugraph-cu12 pylibcugraph-cu12 cucim-cu12
# Out:
# Found existing installation: cudf-cu12 26.2.1
# Uninstalling cudf-cu12-26.2.1:
#   Successfully uninstalled cudf-cu12-26.2.1
# Found existing installation: cuml-cu12 26.2.0
# Uninstalling cuml-cu12-26.2.0:
#   Successfully uninstalled cuml-cu12-26.2.0
# Found existing installation: dask-cudf-cu12 26.2.1
# Uninstalling dask-cudf-cu12-26.2.1:
#   Successfully uninstalled dask-cudf-cu12-26.2.1
# Found existing installation: nx-cugraph-cu12 26.2.0
# Uninstalling nx-cugraph-cu12-26.2.0:
#   Successfully uninstalled nx-cugraph-cu12-26.2.0
# Found existing installation: pylibcugraph-cu12 26.2.0
# Uninstalling pylibcugraph-cu12-26.2.0:
#   Successfully uninstalled pylibcugraph-cu12-26.2.0
# Found existing installation: cucim-cu12 26.2.0
# Uninstalling cucim-cu12-26.2.0:
#   Successfully uninstalled cucim-cu12-26.2.0

# %%
# !git clone https://github.com/runew0lf/RuinedFooocus.git
# Out:
# fatal: destination path 'RuinedFooocus' already exists and is not an empty directory.

# %%
# !pip install -r ./RuinedFooocus/requirements_versions.txt

# %%
# !pip uninstall -y cupy cupy-cuda12x cupy-cuda11x
# !pip install numpy==1.26.4
# !pip install cupy-cuda12x==12.3.0
# Out:
# WARNING: Skipping cupy as it is not installed.
# WARNING: Skipping cupy-cuda12x as it is not installed.
# WARNING: Skipping cupy-cuda11x as it is not installed.
# ...
#   Using cached cupy_cuda12x-12.3.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (2.7 kB)
# ...
# Using cached cupy_cuda12x-12.3.0-cp312-cp312-manylinux2014_x86_64.whl (82.1 MB)
# ...

# %%
# !python ./RuinedFooocus/entry_with_update.py --share
# Out:
# Check pre-requirements
# You have the latest version
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# RuinedFooocus version: 26.03.16
# Check pip
# Check pre-requirements
# Check for old modules
# Torch platform: Linux: cpu
# >  ['/usr/bin/python3', '-m', 'pip', 'install', 'torch', 'torchaudio', 'torchvision']
# ...
# ComfyUI update check complete.
# ComfyUI-GGUF update check complete.
# Starting webui
# WARNING:root:WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# 2026-04-02 09:24:33.490581: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775121873.513003    6007 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
